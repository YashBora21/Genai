# %%
from langchain.document_loaders import TextLoader
loader=TextLoader('speech.txt')
loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from Langchain_community.documnet_Loaders import TextLoader
#       2 loader=TextLoader('speech.txt')
#       3 loader.load()
#
# ModuleNotFoundError: No module named 'Langchain_community'

# %%
from Langchain_community.documnet_Loaders import PyPDFLoader
loader=TextLoader('speech.txt')
loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Langchain_community.documnet_Loaders import PyPDFLoader
#       2 loader=TextLoader('speech.txt')
#       3 loader.load()
#
# ModuleNotFoundError: No module named 'Langchain_community'
