# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(model="gemma4:31b-cloud")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_37528\1387038699.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="gemma4:31b-cloud")

# %%
result= embeddings.embed_query("What is Ollama?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result= embeddings.embed_query("What is Ollama?")
#
# File c:\Users\Lenovo\OneDrive\Desktop\Lanchain_k\venv\lib\site-packages\langchain_community\embeddings\ollama.py:227, in OllamaEmbeddings.embed_query(self, text)
#     218 """Embed a query using a Ollama deployed embedding model.
#     219
#     220 Args:
#    (...)
#     224     Embeddings for the text.
#     225 """
#     226 instruction_pair = f"{self.query_instruction}{text}"
# --> 227 embedding = self._embed([instruction_pair])[0]
#     228 return embedding
#
# File c:\Users\Lenovo\OneDrive\Desktop\Lanchain_k\venv\lib\site-packages\langchain_community\embeddings\ollama.py:202, in OllamaEmbeddings._embed(self, input)
#     200 else:
#     201     iter_ = input
# --> 202 return [self._process_emb_response(prompt) for prompt in iter_]
#
# ...

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
result = embeddings.embed_query("What is Ollama?")
print(len(result))
# Out:
# 768

# %%
result = embeddings.embed_documents(["What is Ollama?"])
print(len(result[0]))
# Out:
# 768
